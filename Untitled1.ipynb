# %% [markdown]
# <a href="https://colab.research.google.com/github/alyablank23-stack/my-python-app/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fastapi uvicorn sqlalchemy psycopg2-binary passlib[bcrypt] python-jose
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 20.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.6/525.6 kB 37.4 MB/s eta 0:00:00
# ...

# %%
# %%writefile database.py
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

SQLALCHEMY_DATABASE_URL = "sqlite:///./studybuddy.db"  # use SQLite for Colab demo
# For production: "postgresql://user:password@host/studybuddy"

engine = create_engine(SQLALCHEMY_DATABASE_URL, connect_args={"check_same_thread": False})
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
Base = declarative_base()
# Out:
# Writing database.py

# %%
# %%writefile models.py
from sqlalchemy import Column, Integer, String
from database import Base

class User(Base):
    __tablename__ = "users"
    id = Column(Integer, primary_key=True, index=True)
    name = Column(String, nullable=False)
    email = Column(String, unique=True, index=True, nullable=False)
    password = Column(String, nullable=False)
    college = Column(String, nullable=True)
    goal = Column(String, nullable=True)
# Out:
# Writing models.py

# %%
# %%writefile crud.py
from sqlalchemy.orm import Session
from models import User
from passlib.context import CryptContext
from pydantic import BaseModel

pwd_context = CryptContext(schemes=["bcrypt"], deprecated="auto")

class UserCreate(BaseModel):
    name: str
    email: str
    password: str
    college: str | None = None
    goal: str | None = None

def get_user_by_email(db: Session, email: str):
    return db.query(User).filter(User.email == email).first()

def create_user(db: Session, user: UserCreate):
    hashed_pw = pwd_context.hash(user.password)
    db_user = User(name=user.name, email=user.email, password=hashed_pw,
                   college=user.college, goal=user.goal)
    db.add(db_user)
    db.commit()
    db.refresh(db_user)
    return db_user

def authenticate_user(db: Session, email: str, password: str):
    user = get_user_by_email(db, email)
    if not user or not pwd_context.verify(password, user.password):
        return None
    return user
# Out:
# Writing crud.py

# %%
# %%writefile main.py
from fastapi import FastAPI, Depends, HTTPException
from sqlalchemy.orm import Session
from jose import jwt
from datetime import datetime, timedelta
from database import SessionLocal, engine, Base
import models, crud

SECRET_KEY = "supersecretkey"
ALGORITHM = "HS256"

app = FastAPI(title="Study Buddy API", version="1.0.0")

Base.metadata.create_all(bind=engine)

def get_db():
    db = SessionLocal()
    try:
        yield db
    finally:
        db.close()

def create_access_token(data: dict, expires_delta: timedelta | None = None):
    to_encode = data.copy()
    expire = datetime.utcnow() + (expires_delta or timedelta(minutes=30))
    to_encode.update({"exp": expire})
    return jwt.encode(to_encode, SECRET_KEY, algorithm=ALGORITHM)

@app.post("/register")
def register(user: crud.UserCreate, db: Session = Depends(get_db)):
    db_user = crud.get_user_by_email(db, email=user.email)
    if db_user:
        raise HTTPException(status_code=400, detail="Email already registered")
    new_user = crud.create_user(db, user)
    token = create_access_token({"sub": new_user.email})
    return {"access_token": token, "token_type": "bearer"}

@app.post("/login")
def login(user: crud.UserCreate, db: Session = Depends(get_db)):
    db_user = crud.authenticate_user(db, user.email, user.password)
    if not db_user:
        raise HTTPException(status_code=401, detail="Invalid credentials")
    token = create_access_token({"sub": db_user.email})
    return {"access_token": token, "token_type": "bearer"}

@app.get("/dashboard")
def dashboard():
    return {
        "message": "Good Morning, Alya!",
        "today_progress": "3 hours studied",
        "upcoming_classes": ["Math 10 AM", "Physics 2 PM"],
        "assignments": ["Essay due tomorrow"],
        "study_streak": 5,
        "leaderboard_position": 12
    }
# Out:
# Writing main.py

# %%
import os
# !pip install uvicorn
# !nohup uvicorn main:app --host 0.0.0.0 --port 8000 --reload &
# !pip install pyngrok
from pyngrok import ngrok

# Replace 'YOUR_NGROK_AUTH_TOKEN' with your actual ngrok authtoken
# You can find your authtoken at https://dashboard.ngrok.com/get-started/your-authtoken

# The authtoken below is an example. Please replace it with your actual token.
NGROK_AUTH_TOKEN = "3GCdhptcuF4uLh3iH8JVYbPmxnP_6oCqBfyBgStVL7HRLU2qs" # <-- Replace with your actual token!
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Check if the tunnel is already open to prevent multiple tunnels
active_tunnels = ngrok.get_tunnels()
if not active_tunnels:
    public_url = ngrok.connect(8000).public_url
    print("Public URL:", public_url)
else:
    print("ngrok tunnel already active:", active_tunnels[0].public_url)
# Out:
# ...
# nohup: appending output to 'nohup.out'
# ...
# Public URL: https://justifier-catnip-flashback.ngrok-free.dev

# %%
import requests

# Ensure public_url is available from the previous cell's execution
if 'public_url' not in locals() or not public_url:
    print("Error: ngrok public_url not found. Please run the ngrok cell first.")
else:
    print(f"Testing endpoint on: {public_url}/dashboard")
    r = requests.get(f"{public_url}/dashboard")
    print("Dashboard Response:", r.json())

    # Example: Register a new user (replace with actual data)
    print(f"Testing endpoint on: {public_url}/register")
    register_data = {
        "name": "Test User",
        "email": "test@example.com",
        "password": "password123",
        "college": "Colab University",
        "goal": "Learn FastAPI"
    }
    try:
        r_register = requests.post(f"{public_url}/register", json=register_data)
        print("Register Response:", r_register.json())
    except requests.exceptions.HTTPError as e:
        print(f"HTTP Error during registration: {e.response.json()}")
    except Exception as e:
        print(f"An unexpected error occurred during registration: {e}")

    # Example: Login a user
    print(f"Testing endpoint on: {public_url}/login")
    login_data = {
        "name": "", # Not used in login endpoint, but part of UserCreate model
        "email": "test@example.com",
        "password": "password123"
    }
    try:
        r_login = requests.post(f"{public_url}/login", json=login_data)
        print("Login Response:", r_login.json())
    except requests.exceptions.HTTPError as e:
        print(f"HTTP Error during login: {e.response.json()}")
    except Exception as e:
        print(f"An unexpected error occurred during login: {e}")
# Out:
# Testing endpoint on: https://justifier-catnip-flashback.ngrok-free.dev/dashboard
# Dashboard Response: {'message': 'Good Morning, Alya!', 'today_progress': '3 hours studied', 'upcoming_classes': ['Math 10 AM', 'Physics 2 PM'], 'assignments': ['Essay due tomorrow'], 'study_streak': 5, 'leaderboard_position': 12}
# Testing endpoint on: https://justifier-catnip-flashback.ngrok-free.dev/register
# An unexpected error occurred during registration: Expecting value: line 1 column 1 (char 0)
# Testing endpoint on: https://justifier-catnip-flashback.ngrok-free.dev/login
# Login Response: {'detail': 'Invalid credentials'}
